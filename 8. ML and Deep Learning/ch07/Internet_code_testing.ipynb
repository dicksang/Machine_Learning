# %%
# !pip install jieba
# Out:
# Collecting jieba
#   Downloading https://files.pythonhosted.org/packages/71/46/c6f9179f73b818d5827202ad1c4a94e371a29473b7f043b736b4dab6b8cd/jieba-0.39.zip (7.3MB)
# Building wheels for collected packages: jieba
#   Running setup.py bdist_wheel for jieba: started
#   Running setup.py bdist_wheel for jieba: finished with status 'done'
#   Stored in directory: C:\Users\Dick Sang\AppData\Local\pip\Cache\wheels\c9\c7\63\a9ec0322ccc7c365fd51e475942a82395807186e94f0522243
# Successfully built jieba
# Installing collected packages: jieba
# Successfully installed jieba-0.39
# You are using pip version 18.1, however version 19.3.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import AutoSummary as ausu
import requests
from bs4 import BeautifulSoup as soup

# %%
stops = []
with open('dictionary/stopWord_summar.txt','r', encoding='utf8') as f:  #停用詞庫
    for line in f.readlines():
        stops.append(line.strip())

urls = []
url = 'https://udn.com/news/breaknews/1'  #聯合報新聞
html = requests.get(url)
sp = soup(html.text, 'html.parser')
data1 = sp.select('#breaknews_body dl dt h2 a')

# %%
for d in data1:  #取得新聞連結
    urls.append('https://udn.com' + d.get('href'))

# %%
i = 1
for url in urls:  #逐一取得新聞
    html = requests.get(url)
    sp = soup(html.text, 'html.parser')
    data1 = sp.select('#story_body_content p')  #新聞內容
    # break the program process if item is greater than 50
    if i > 50:
        break
    print('處理第 {} 則新聞'.format(i))
    text = ''
    for d in data1:
        if d.text.find('延伸閱讀') != -1:  #遇到延伸閱讀就結束此則新聞
            break
        if d.text != '':  #有新聞內容
            text += d.text
    sentences,indexs = ausu.split_sentence(text)  #按標點分割句子
    tfidf = ausu.get_tfidf_matrix(sentences,stops)  #移除停用詞並轉換為矩陣
    word_weight = ausu.get_sentence_with_words_weight(tfidf)  #計算句子關鍵詞權重
    posi_weight = ausu.get_sentence_with_position_weight(sentences)  #計算位置權重
    scores = ausu.get_similarity_weight(tfidf)  #計算相似度權重
    sort_weight = ausu.ranking_base_on_weigth(word_weight, posi_weight, scores, feature_weight = [1,1,1])
    summar = ausu.get_summarization(indexs,sort_weight,topK_ratio = 0.3)  #取得摘要
    print(summar)
    print('==========================================================')
    i += 1
# Out:
# 處理第 1 則新聞
# 印度通過公民法修正案引發的示威16日持續延燒，發生示威的地區從印度東北部蔓延到首都新德里等城市。這項法案允許孟加拉、阿富汗、巴基斯坦三個印度鄰國遭受宗教迫害的民眾可有條件取得印度國籍，但排除穆斯林。示威者之中有人認為這會鼓勵非法移民，有人認為這個法律歧視穆斯林，因此上街抗議與軍警發生衝突，連日的示威衝突已造成6人死亡。印度總理莫迪堅稱他並未歧視穆斯林，他說，公民法「百分之1000正確」，排除這三個鄰國的穆斯林，是因為他們不需要印度保護，他並指控最大反對黨國大黨「搧風點火」。國大黨前黨魁拉胡爾．甘地發推文批評說，政府修改公民法和先前公布全國公民名冊，都是「法西斯分子造成社會大規模對立的手段」。」位於新德里、主要培養穆斯林學生的國立伊斯蘭大學，原本有連續三天的和平示威，15日深夜示威升級，數千名示威者與警方爆發衝突，警方動用橡膠棒和催淚瓦斯驅趕示威者。
# ==========================================================
# ==========================================================
# 處理第 16 則新聞
# 桃園市長鄭文燦今晚為民進黨新北第11選區立委候選人張銘祐站台，鄭文燦說，他第一次選桃園市長時也很辛苦，但相信沒有一個地方是鐵板塊，盼新店可以改變。鄭文燦呼籲，要把選票盡量拉高，張銘祐變立委機會也變大，相信正確價值跟當選以後能夠超越政治包袱，就讓每個市民能感動，沒有一個地方是鐵板塊，盼新店可以改變。
# ==========================================================
# 處理第 17 則新聞
#  聯合報系資料照片／記者陳易辰攝影 分享   facebook     中央氣象局今天指出，26日將發生日環食，台灣雖不在環食帶上，但各地在天氣許可時，可見不同程度的日偏食；明年6月21日，再次有日環食，金門、澎湖、嘉義及台東等可看得到。氣象局表示，12月26日的日環食，當天在台灣時間上午10時30分至下午4時6分，歷經5小時又36分鐘，環食帶通過沙烏地阿拉伯、印度南部、馬來半島南部及婆羅洲等地，能看見日偏食的地區包括亞洲及澳洲北側，台灣不在環食帶上，只能見到日偏食，自北而南約可見33%至38%的日面缺角。
# ==========================================================
# 處理第 18 則新聞
# 遠東航空12日宣布無預警停飛，根據遠航回報資料，截至今天為止總共受理4萬1607筆退票。
# ==========================================================
# 處理第 19 則新聞
# 北韓要求美方提交新的談判建議，否則北韓就會「開闢新的道路」，而美國則將得到一份「不詳的聖誕禮物」。北韓官方通訊社發布的照片顯示，北韓領導人金正恩在妹妹金與正和兩名親信的陪同下，再度騎馬登上了白頭山。過去的經驗顯示，最高領導人現身白頭山，預示著將有重大決議要公布。北韓要求美方提交新的談判建議，否則北韓就會「開闢新的道路」，而美國則將得到一份「不詳的聖誕禮物」。北韓官方通訊社發布的照片顯示，北韓領導人金正恩在妹妹金與正和兩名親信的陪同下，再度騎馬登上了白頭山。今年二月，美國與北韓在河內的會談以失敗告終後，北韓發起了內容廣泛的威脅攻勢，而白頭山充滿擺拍意味的畫面顯然也是這一攻勢的組成部分。四月中旬，金正恩發出最後通牒，要求美國在年底前提出可接受的談判建議。12月7日，北韓當局為西海試驗基地「一次重要的試射」舉行盛大慶典。今年年內，北韓方面已經進行了二十次類似的導彈試驗。今年二月，美國與北韓在河內的會談以失敗告終後，北韓發起了內容廣泛的威脅攻勢，而白頭山充滿擺拍意味的畫面顯然也是這一攻勢的組成部分。四月中旬，金正恩發出最後通牒，要求美國在年底前提出可接受的談判建議。12月7日，北韓當局為西海試驗基地「一次重要的試射」舉行盛大慶典。今年年內，北韓方面已經進行了二十次類似的導彈試驗。川普嚴詞警告「火箭人」北韓頻頻進行導彈試驗引起美方強烈不滿。而此前一天，美國軍方一架全球鷹系列無人機和一家監測機飛躍北韓半島，此外，一家具備核彈攜帶能力的美軍B-52H轟炸機也出現在日本海域。北韓頻頻進行導彈試驗引起美方強烈不滿。而此前一天，美國軍方一架全球鷹系列無人機和一家監測機飛躍北韓半島，此外，一家具備核彈攜帶能力的美軍B-52H轟炸機也出現在日本海域。制裁是爭議核心多數觀察家認為，北韓領導人金正恩之所以日趨強硬，是因為他期望能夠在不承諾放棄核計劃的前提下，大幅度取消聯合國對北韓的制裁令。多數觀察家認為，北韓領導人金正恩之所以日趨強硬，是因為他期望能夠在不承諾放棄核計劃的前提下，大幅度取消聯合國對北韓的制裁令。北韓問題的一個可能前景是，北韓承諾不再進行導彈試驗，並關閉永邊核反應堆。華盛頓戰略及國際問題研究中心的車維德（Victor Cha）對美朝談判前景一向持悲觀立場，但他也認為：「一旦美國放鬆制裁，雙方即可很快達成協議。」北韓問題的一個可能前景是，北韓承諾不再進行導彈試驗，並關閉永邊核反應堆。華盛頓戰略及國際問題研究中心的車維德（Victor Cha）對美朝談判前景一向持悲觀立場，但他也認為：「一旦美國放鬆制裁，雙方即可很快達成協議。無論川普能否當選連任，還是由民主黨人取而代之，未來的美國總統都將面對一個難以對付的北韓：該國擁有先進的核武和導彈系統，又能成功躲避國際制裁，因此很難逼迫北韓就範。無論川普能否當選連任，還是由民主黨人取而代之，未來的美國總統都將面對一個難以對付的北韓：該國擁有先進的核武和導彈系統，又能成功躲避國際制裁，因此很難逼迫北韓就範。華盛頓史汀生中心「三八線以北項目」的軍事專家埃勒門（Michael Elleman）表示，前不久北韓方面宣傳的西海試驗場「重大試驗」可能就是測試推動力更大的火箭推進技術。華盛頓史汀生中心「三八線以北項目」的軍事專家埃勒門（Michael Elleman）表示，前不久北韓方面宣傳的西海試驗場「重大試驗」可能就是測試推動力更大的火箭推進技術。
# ==========================================================
# 處理第 20 則新聞
# 網路流傳雲林民進黨立委蘇治芬宣傳車司機，日前扯下對手國民黨立委候選人張嘉郡布條，張嘉郡今再直指蘇親自割斷布條，並由律師陪同提告；蘇的競選辦公室回應，蘇委員不可能割布條，針對涉及黑函的布條也將提告。張嘉郡今天再指有目擊者12月8日看到蘇治芬，在雲153縣道下車親自與助理割斷「農委會不當決標進口花生，雲林縣政府對地補貼2000元」與「鄉親評鑑，張嘉郡建設一百分，蘇治芬簽到一百分」兩個布條，涉犯選罷法和毀損罪。蘇治芬競選辦公室發言人邱世文回應，日前團隊內部提醒「鄉親評鑑張嘉郡建設一百分」的布條是黑函，司機所為只能是護主心切，但該布條屬黑函本就違法。
# ==========================================================
# 處理第 21 則新聞
# 波特王（右）稱蔡英文「總統」被中國打壓，蘇貞昌表示，可見台灣民主多珍貴。圖／截自波特王臉書粉絲頁 分享   facebook     行政院長蘇貞昌今晚前往汐止參加民進黨第12選區立委候選人賴品妤聯合座談會，被問到網紅「波特王」及國民黨總統候選人韓國瑜批交通部卡愛情摩天輪2議題，蘇貞昌表示，由此可見台灣民主自由的可貴。波特王與蔡英文合作拍影片，卻因稱呼蔡「總統」遭中國大陸合作廠商「徐州自由自在網路科技公司（papitube）」要求下架，波特王團隊則表示「真的跪不下去」，霸氣直接與對方解約。
# ==========================================================
# 處理第 22 則新聞
# ==========================================================
# 處理第 27 則新聞
# 圖／取自飆捍粉專 分享   facebook     「館長」陳之漢去年在九合一大選時，在直播節目與高雄市長韓國瑜直播，不過韓當選後，館長認為韓國瑜幾乎都打臉當初節目上所講過的話，而近期館長喊出「支持蔡英文」，甚至說出若蔡英文總統勝選，他將請1萬份雞排。館長也在直播中提到，歡迎各黨政治人物，今晚間館長在臉書宣布，「韓辦發言人邀約直播，我答應了大家拭目以待」。
# ==========================================================
# 處理第 28 則新聞
# 記者陳俊智／翻攝 分享   facebook     新北市板橋區繼上個月「滷肉飯千金」之後，本月15日再傳擄人案，但偵辦這兩起案件的海山警方堅稱昨天發生的案件是雙方有債務糾紛，被害人也不願提告，所以只能依社會秩序維護法偵辦，辦案強度比起上次擄人未遂還薄弱，不免讓人質疑「大案小辦」。刑法第302條第一項規定「私行拘禁或以其他非法方法，剝奪人之行動自由者，處五年以下有期徒刑」，第304條也規定「以強暴、脅迫使人行無義務之事或妨害人行使權利者，處三年以下有期徒刑、拘役或三百元以下罰金」，2條法律都是「未遂犯罰之」，簡而言之，擄人不管有沒有成功都構成刑責。
# ==========================================================
# 處理第 29 則新聞
# 儘管生涯成績優於姊姊大威廉絲（Venus Williams），美國名將小威廉絲（Serena Williams）最佩服的還是自己的姊姊，最大原因就是因為大威受到傷病挑戰，卻依舊努力在單打賽場上奮戰，「她的這種精神令人覺得不可思議。」身為近代網壇最佳姐妹檔代表，大、小威廉絲共打下30座大滿貫女單金盃，其中小威生涯累積的23座大滿貫賽單打金盃，僅次於澳洲傳奇女將寇特（Margaret Court）。不過大威在2011年遭診斷出自體免疫疾病修格蘭氏症候群（Sjogrens syndrome），俗稱乾燥症候群，大威也曾表示，症狀在嚴重時連抬起手臂都十分困難，但是大威沒有因此放棄網球生涯，反倒一直在賽場拚搏，也努力維持在較高水平。
# ==========================================================
# 處理第 30 則新聞
# 近年來訂閱經濟崛起，線上訂閱服務如行動應用程式及網際網路影音串流服務等業者，常採自動續約扣款方式提供服務，但自動續約相關資訊標示不明、解約困難，導致消費糾紛不少；北市法務局指出，近3個月申訴案量最大者為蘋果新聞網及壹週刊自動續約爭議，約130多件；業者則表示，事前都有善盡告知義務，後續也有改善作法。法務局指出，自動續約條款常隱藏在密密麻麻的服務條款中，契約屆期未經消費者明示同意就自動續約，解約方式繁雜不清楚，客服又難以聯繫或無法有效解決問題，常衍生消費爭議；例如訂閱數位新聞、線上影規或音樂串流服務、文件圖像或影音編輯軟體、線上教學、線上遊戲、交友軟體等都有相關申訴案件。
# ==========================================================
# 處理第 31 則新聞
#  聯合報系資料照片／記者何佩儒攝影 分享   facebook     宏達電近年營運較過去下滑，雖積極衝刺VR改善毛利率，但營收動能尚未顯著放大，今天證實裁員，以確保VIVE與手機事業發展。不具名分析師表示，VR發展速度沒預期的好，宏達電還在尋找自己的定位。隨著智慧型手機步入紅海，宏達電2013年驚見上市以來首度虧損，董事長王雪紅決定切入虛擬實境（VR）事業，拓展營運的第二隻腳，但VR發展速度不如預期。儘管王雪紅信誓旦旦喊話，宏達電明年會推出突破性的VR和擴增實境（AR）產品，但產業分析師認為，VR市場仍有不少問題需要解決，例如用戶數不足、資金集中在硬體製造上，宏達電想靠VR扭轉命運，在轉型過程中勢必還會面對許多困難。
# ==========================================================
# 處理第 32 則新聞
# 國民黨立委候選人張志明主張「台鐵台東-台北、台東─高雄每天至少有直達車來回各一班」，方便台東民眾往返台北、高雄洽公或就醫，也解決台東民眾買不到火車票的問題。張志明表示，他當選後，一定會要求台鐵在現有花東實名制度外，並且進一步推動台東-台北、台東─高雄，每天至少各1班來回直達車，讓台東民眾回家的路更方便順暢。
# ==========================================================
# 處理第 33 則新聞
# 新北三重中興橋下空間被新北市水利局設計活化為兒童遊戲區「鴨鴨遊戲場」，因位在高灘地，全國首創可拆卸式的3.5公尺高大型造型溜滑梯。為推動新北特色、共融及全齡化公園，新北市高灘地工程管理處自今年4月起，推動「公園特色共融或全齡化改善計畫」，昨啟用新北第14處特色共融遊戲場「鴨鴨遊戲場」，預計明年底至少完成41處。新北市侯友宜作也前往現場視察，並體驗自行車躍動設施，推廣新北高灘地河岸遼闊風光及趣味遊具，讓民眾在市區就能享受河邊完善便利設施，也讓孩童能體驗遊戲場各項活動。記者胡瑞玲／攝影 分享   facebook     新北市高管處在三重鴨鴨公園旁打造新北第14處特色共融遊戲場「鴨鴨遊戲場」。
# ==========================================================
# 處理第 34 則新聞
# 台北地院女法官唐玥審理前總統馬英九洩密案，判馬英九無罪，監察委員陳師孟認為審判過程有調查的必要，決定下月約詢唐玥；唐玥今天說，她尊重陳師孟的約詢，會準備資料應答，「我尊重他，也盼望他能尊重司法」。
# ==========================================================
# 處理第 35 則新聞
# 屏東縣沿海鄉鎮是石斑魚養殖重鎮，馬英九執政時期和大陸簽訂ECFA、喊出「石斑魚產值倍增」，在沿海傳統綠營票倉搶走不少綠營選票；ECFA明年9月屆滿10年，屏東縣養殖業網路社群最近出現一則「警訊」，指ECFA屆滿10年時，海峽兩岸若未提出需要超過10年的過渡期來協商「貨貿」 和「服貿」等主協定，架構協議將自然失效，這則訊息也攪動著養殖戶的總統選票動向。」屏東縣陳姓養殖業者說，網傳ECFA明年到期，台灣對「兩岸貨貿協議」與「兩岸服貿協議」若遲遲不推，大陸有正當理由終止，數百項農、漁產品的免稅優惠將取消；屏東縣石斑魚養殖業九成市場靠外銷港澳和大陸，上千家庭靠此維生，讓養殖戶對下月的總統大選，陷入「顧肚子」和「顧佛祖」的掙扎。
# ==========================================================
# 處理第 36 則新聞
# 」不過有網友表示，明明都是解約，為何館長（陳之漢）聲量沒有波特王高，有人則點出關鍵因素在「選舉時間」！
# ==========================================================
# 處理第 37 則新聞
# 國民黨總統候選人韓國瑜今天晚間到高雄鳳山參加高雄市義勇消防總隊表揚大會，頒發感謝狀給近千名服務年資滿30年及15年的義消弟兄。高雄市有968位年資滿15年的義消人員，其中30年以上更有78人，高雄市義勇消防總隊總隊長陳義永說，全市編制內有4533名義消，加上編制外有5500人，有如一個大家庭，非常溫馨；韓市長上任後，今年7月起將鳳凰志工正式納入救護大隊，讓他們能擁有更好的福利。
# ==========================================================
# 處理第 38 則新聞
# 日前台南市白河柑橘果農反映找不到工人採收導致損失百萬，農委會今天表示，已自將軍區調度技術團人力前往支援，將依據該名果農需求在果樹生理調節後協助採收。白河地區果農反映缺乏採果工人問題，農委會說，已馬上調度將軍區的農業技術團前往支援，由於該果農種植柑橘面積約4公頃、產量近40萬斤，因12月初遇到寒流及下雨，已屆採收的果實遭受雨傷及凍傷，目前近5成規畫於果樹生理調節後採收，農委會將適時提供人力協助採收。
# ==========================================================
# 處理第 39 則新聞
# 圖／中央氣象局提供 分享   facebook     今晚7時25分在宜蘭縣南澳鄉發生規模5.0地震，地震深度49公里。中央氣象局地震測報中心主任陳國昌說，不排除兩、三天內發生規模3.0以上的餘震，此次地震因深度較深導致震波傳遞慢，中部以北地區幾乎都有感。
# ==========================================================
# 處理第 40 則新聞
#  聯合報系資料照片／記者陳柏亨攝影 分享   facebook     負責馬英九洩密案一審的台北地方法院法官唐玥，將馬判決無罪。事實上，陳師孟去年4月就在個人部落格「尖尾週記」當中，批評唐玥判馬無罪的法律見解，根本就是枉法。他當時並表示，自己手握彈劾權，在馬英九有罪定讞之後，「尖尾（陳師孟文中自稱）將會找上妳」。陳師孟於去年4月7日在部落格「尖尾週記」發表文章「這不是枉法裁判，什麼才是？
# ==========================================================
# 處理第 41 則新聞
#
# ==========================================================
# C:\Users\Dick Sang\Desktop\5. Data Analytics\2. Statistic tool\1. Python\8. ML and Deep Learning\ch07\AutoSummary.py:44: RuntimeWarning: invalid value encountered in double_scalars
#   sentence_with_words_weight[key] = (x-min_weight)/(max_weight-min_weight)
# C:\Users\Dick Sang\Desktop\5. Data Analytics\2. Statistic tool\1. Python\8. ML and Deep Learning\ch07\AutoSummary.py:68: RuntimeWarning: invalid value encountered in double_scalars
#   sentence_score[key] = (x-min_score)/(max_score-min_score)
# 處理第 42 則新聞
#
# ==========================================================
# 處理第 43 則新聞
# 金門縣政府為因應停航事件，今由縣長楊鎮浯率同觀光處長丁健剛前往拜會星宇航空，希望除緩解遠航帶來的衝擊，也為金門航空旅運，提供不一樣的選擇。星宇航空公關長聶國維表示，如果民航局整體考量後，認為有需要星宇協助，會再進行評估。觀光處表示，遠航停航事件發生第一時間成立應變小組，同時立即協請民航局協調其他航空公司增加航班因應，除立即解決往返金門的鄉親與旅客機位服務外，也在縣府、觀光處3樓及各鄉鎮公所服務台及網路平台，提供登記服務，以便掌握相關資訊，為鄉親爭取權益。
# ==========================================================
# 處理第 44 則新聞
# 南投縣中興高中學生周昕儀因家境清貧，從小得上山幫忙除草、割檳榔，協助家中生計，但她從不喊苦，更正向看待逆境、樂觀求學，大學特殊選才近期陸續放榜，她同時錄取清大清華學院學士班及成大全校不分系學士位學程，成績亮眼。中興高中指出，109學年度大學多元入學招生管道「特殊選才」陸續放榜，而今年參與的47校458學系僅提供1214個招生名額，其中國立清華大學清華學院學士班共703人報名，錄取33人，競爭相當激烈，周仍從眾多人選中脫穎而出。
# ==========================================================
# 處理第 45 則新聞
# 陳師孟調查對陳水扁不友善的檢察官後，又要調查對馬英九友善的法官，將監察委員職權的行使，當成個人意識型態的一場表演；陳師孟是「監委」卻自闢「尖尾」週記撰文寫專欄，監察委員連自己的職銜都不懂得尊重，對於平行的司法權，自然不會放在眼裡。法官審案在行使國家司法權，當裁判不嚴謹或有疏漏，就會被上級審撤銷或廢棄；法官所執的法，是立法委員通過的法案，法令不合時宜，可建議修法求改正，絕無可能不按照既有法律去判決，道理說的就是「司法權對立法權的尊重」。
# ==========================================================
# 處理第 46 則新聞
# 香港特首林鄭月娥今日晚間在北京在香港駐京辦向媒體總結北京述職行程。林鄭月娥表示，他感謝北京肯定香港維護社會穩定工作及紓困措施，並說北京堅定支持警方執法，及港府人團結一致。林鄭月娥說，香港經濟要重回正軌需要北京在政策上的支持，香港社會存在深層次矛盾，需認真研究及努力解決，並指呼應港府成立獨立檢討委員會。
# ==========================================================
# 處理第 47 則新聞
# 近期日本玩具品牌「T-ARTS」以暴牙為靈感，推出全新「暴牙動物」公仔，包括暴牙獅子、暴牙熊貓、暴牙猴、暴牙龜及暴牙蠑螈等六種，晉升辦公室最夯解壓小物。 「暴牙獅子」專注神情搭配20~30公分超長暴牙，讓萬獸之王獅子瞬間失去威嚴感，反而充滿逗趣風格，讓粉絲驚呼太可愛了！ 「暴牙龜」可達到身長135公分，背上醒目龜殼為其識別標誌，碩大門牙視覺感十足，緩慢爬行的暴牙龜搖擺身軀，從遠處看來宛如一顆巨大岩石；「暴牙猴」紅通通臉龐襯以突出門牙妝點，雙腿盤坐仰望天際，好像在進行無言的抗議，充滿逗趣感。
# ==========================================================
# 處理第 48 則新聞
# 俄羅斯日前遭世界反運動禁藥組織（World Anti-Doping Agency）處以四年全面禁賽，儘管俄羅斯運動員只要證明自身清白，仍能以中立運動員（獨立運動員）身分參賽，但美國奧委員會（USOC）指出，要證明清白會極其艱鉅。WADA本月9日決議對俄羅司處以四年禁賽，接下來四年禁止俄羅斯政府和運動協會申辦國際會，俄羅斯國旗、國歌亦不得出現在運動賽會，影響其明年東京奧運、2022年北京冬季奧運以及2022年卡達世足賽參賽權。
# ==========================================================
# 處理第 49 則新聞
#
# ==========================================================
# 處理第 50 則新聞
# YouTube執行長日前表示，她不會讓小孩長時間使用該網站。路透 分享   facebook     日前，YouTube CEO蘇珊・沃捷斯基（Susan Wojciki）在受訪時表示，她會限制自己的小孩使用YouTube的時間，而且只會讓他們使用YouTube Kids。
# ==========================================================
